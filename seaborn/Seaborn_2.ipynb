# %% [markdown]
# # Plotting with Categorical Data

# %% [markdown]
# ### catplot[Figure Level Function]

# %% [markdown]
# 1. Categorical Scatterplots
# - Stripplot
# - Swarmplot
# 2. Categorical Distribution plots
# - Boxplot
# - Violinplot
# 3.Categorical estimate plots
# - Pointplot
# - Barplot
# - Countplot
# 4.Categorical Categorical plot
# - Heatmaps
# - Clustermaps
# 5.plotting side by side graphs using FacetGrid

# %% [markdown]
# ### Categorical Scatterplots

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
#x-axis --> Categorical Data
#y-axis --> Numerical Data

# %%
plt.style.use('fivethirtyeight')

# %%
tips=sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#strip plot
sns.catplot(x='day',y='tip',kind='strip',jitter='0.3',data=tips)

# %%
#swarm plot
sns.catplot(x='day',y='tip',kind='swarm',data=tips)
# Out:
# /Users/shresthmurarka/opt/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 8.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
#hue 
sns.catplot(x='day',y='tip',kind='swarm',hue='sex',data=tips)
# Out:
# /Users/shresthmurarka/opt/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 8.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(x='day',y='tip',data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>
