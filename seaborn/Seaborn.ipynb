# %% [markdown]
# ## Relational/Statistical Plots

# %% [raw]
# Relational plots are used to perform multivariate analysis
# 1.Scatter plots
# 2.Line plot(specifically used for time series data)
# 3.FacetGrids(Plotting multiple graphs side by side)

# %% [markdown]
# ## Scatter plots

# %% [raw]
# The Scatter plot is a  statistical visualixation . it deplicts the joint distribution of two variable using a clouds of points, where each point represent an observation in dataset.

# %% [raw]
# there are 2 ways to draw a scatterplot in seaborn
# 1. relplot (figure level function)
# 2. scatterplot[axes level function]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
plt.style.use('fivethirtyeight')

# %%
data=sns.load_dataset('tips')

# %%
data.info
# Out:
# <bound method DataFrame.info of      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]>

# %% [markdown]
# ### Plot a Scatter Plot between total_bill and tip

# %%
 sns.relplot(x='total_bill',y='tip',kind='scatter',data=data)

# %% [markdown]
# ### The Hue Parameter

# %%
sns.relplot(x='total_bill',y='tip',hue='smoker',data=data)

# %% [markdown]
# ### The Style Parameter

# %%
sns.relplot(x='total_bill',y='tip',hue='smoker',style='sex',data=data)

# %% [markdown]
# ### The size parameter

# %%
sns.relplot(x='total_bill',y='tip',
            hue='smoker',style='sex',size='size',
            sizes=(15,200),data=data)

# %% [markdown]
# ### Using Scatterplot function

# %%
sns.scatterplot(x='total_bill',y='tip',hue='smoker',style='sex',data=data)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>
